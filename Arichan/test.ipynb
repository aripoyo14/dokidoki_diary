# %%
from openai import OpenAI
client = OpenAI()

diary_input = "今日もとっても疲れたけど、同僚と一緒に海の見える場所で食べたサンドイッチが美味しかった"

response = client.images.generate(
    model="dall-e-3",
    prompt=f"Create a cute illustration based on the following text. \n #text \n {diary_input}",
    size="1024x1024",
    quality="standard",
    n=1,
)

image_url = response.data[0].url

# %%
image_url
# Out:
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-2NoZXOZOTRtldBbSGUNyOnYN/user-cPfusjE0neTFdnqRusUovupn/img-eqcbVyqVpVIgGzOepqFHp2M5.png?st=2024-12-10T05%3A41%3A39Z&se=2024-12-10T07%3A41%3A39Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-12-09T23%3A44%3A09Z&ske=2024-12-10T23%3A44%3A09Z&sks=b&skv=2024-08-04&sig=Hn69CmYXn%2BH1sRALDdq31p6wGgTcWGTbGW62xUmQke4%3D'

# %%
import openai
openai.__version__
# Out:
# '1.57.0'
